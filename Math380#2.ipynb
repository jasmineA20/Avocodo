# %% [markdown]
# <a href="https://colab.research.google.com/github/jasmineA20/Avocodo/blob/main/Math380%232.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
n =10
a = [0 for x in range(n+1)]
a[0]=1000
for i in range(n):
  a[i+1]= -1.2*a[i]+50
print(a)
A = a
plt.plot(a,'-ok')
plt.axis([0,n,-5000,5000])
# Out:
# [1000, -1150.0, 1430.0, -1666.0, 2049.2, -2409.0399999999995, 2940.8479999999995, -3479.017599999999, 4224.821119999999, -5019.785343999998, 6073.7424127999975]
# (0.0, 10.0, -5000.0, 5000.0)
